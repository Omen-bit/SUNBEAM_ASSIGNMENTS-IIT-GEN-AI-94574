# %%
import pandas as pd

# %%
df=pd.read_csv('D:\Sunbeam\SUNBEAM_ASSIGNMENTS-IIT-GEN-AI-94574\Assignments\Day2\products.csv')

# %%
print(df)
# Out:
#    product_id   product_name     category      price   quantity
# 0         101   Wireless Mouse   Electronics     599         25
# 1         102   Keyboard         Electronics     799         15
# 2         103   USB Cable        Accessories     199         50
# 3         104   Notebook         Stationery       49        120
# 4         105   Water Bottle     Home            299         40
# 5         106   Backpack         Bags            899         10
# 6         107   Pen              Stationery       20        300
# 7         108   Headphones       Electronics    1299          8
# 8         109   Coffee Mug       Home            149         60
# 9         110   HDMI Cable       Accessories     299         35

# %%
print(f"Total number of rows : ",len(df))
# Out:
# Total number of rows :  10

# %%
print(df.columns)
# Out:
# Index(['product_id', ' product_name  ', ' category   ', ' price', ' quantity'], dtype='object')

# %%
count=0
for i in df[' price']:
    if i>500:
        count+=1
print("Number of products priced above 500: ",count)
# Out:
# Number of products priced above 500:  4

# %%
average_price=df[' price'].mean()
print("Average price of all products: ",average_price)
# Out:
# Average price of all products:  461.1

# %%
#List all products belonging to a specific category (user input)
category_input = input("Enter the category to filter products: ")
filtered_products = df[df[' category   '] == category_input]
print(f"Products in category '{category_input}':")
print(filtered_products)
# Out:
# Products in category 'Home':
# Empty DataFrame
# Columns: [product_id,  product_name  ,  category   ,  price,  quantity]
# Index: []

# %%
#Total quantity of all items in stock
total_quantity = df[' quantity'].sum()
print("Total quantity of all items in stock: ",total_quantity)
# Out:
# Total quantity of all items in stock:  663
